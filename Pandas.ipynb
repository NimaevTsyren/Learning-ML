# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Yorko/mlcourse.ai/master/data/telecom_churn.csv')
# В raw

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
print(df.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3328     No
# 3329     No
# 3330     No
# 3331    Yes
# 3332     No
# Name: International plan, Length: 3333, dtype: object

# %%
df['Churn'] = df['Churn'].astype('int64')

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include=['object','bool'])
# Описание категориальных переменных
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
df.sort_values(by = 'Area code', ascending = True).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2536    CT             119        408                 No              No
# 887     IA             128        408                 No              No
# 2486    MS              76        408                 No              No
# 2482    MT             157        408                 No              No
# 2476    WV              84        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2536                      0              294.2              100
# 887                       0              158.8               75
# 2486                      0              173.2               93
# 2482                      0              240.2               67
# 2476                      0              146.8              133
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by = ['Area code', 'Account length'], ascending = [True, False]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1408    NM             232        408                 No              No
# 1045    TX             217        408                 No              No
# 1093    VA             210        408                 No              No
# 934     AL             200        408                 No              No
# 364     OK             194        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1408                      0              165.6              104
# 1045                      0              176.4              115
# 1093                      0              104.6              121
# 934                       0              128.2               87
# 364                       0              162.3               88
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492

# %%
df[df['Churn'] == 1].max()
# Out:
# State                        WY
# Account length              225
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        48
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             168
# Total eve charge          30.91
# Total night minutes       354.9
# Total night calls           158
# Total night charge        15.97
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
df[df['Churn'] == 1]['Total day minutes'].sum()
# Out:
# 99939.5

# %%
df[(df['Churn'] == 0) & (df['International plan'] == 'No')]['Total intl minutes'].mean()
# Out:
# 10.185472972972955

# %%
df[(df['Churn'] == 1) & (df['International plan'] == 'Yes')]['Total intl minutes'].mean()
# Out:
# 11.782481751824825

# %%
df.loc[0:7,'State':'Area code']
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510
# 6    MA             121        510
# 7    MO             147        415

# %%
df.iloc[0:7,0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510
# 6    MA             121        510

# %%
df[-1:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3332             39.85              265.9               82              22.6
#
#       Total night minutes  Total night calls  Total night charge  \
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3332                13.7                 4                3.7
#
#       Customer service calls  Churn
# 3332                       0      0

# %%
df[:6]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
# 5                      0              223.4               98
#
# ...

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
d = {'No' : False, 'Yes' : True}
df['International plan'] = df['International plan'].map(d)
df.head()
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 1    OH             107        415               False             Yes
# 2    NJ             137        415               False              No
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df = df.replace({'Voice mail plan': d})
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
columns_to_show = ['Total day minutes', 'Total eve minutes', 'Total night minutes']
a = df.groupby(['Churn'])[columns_to_show].describe(percentiles=[])
print(a)
# Out:
#       Total day minutes                                            \
#                   count        mean        std  min    50%    max
# Churn
# 0                2850.0  175.175754  50.181655  0.0  177.2  315.6
# 1                 483.0  206.914079  68.997792  0.0  217.6  350.8
#
#       Total eve minutes                                             \
#                   count        mean        std   min    50%    max
# Churn
# 0                2850.0  199.043298  50.292175   0.0  199.6  361.8
# 1                 483.0  212.410145  51.728910  70.9  211.3  363.7
#
#       Total night minutes
#                     count        mean        std   min     50%    max
# Churn
# 0                  2850.0  200.133193  51.105032  23.2  200.25  395.0
# 1                   483.0  205.231677  47.132825  47.4  204.80  354.9

# %%
columns_to_show = ['Total day minutes', 'Total eve minutes', 'Total night minutes']
a = df.groupby(['Churn'])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
print(a)
# Out:
#       Total day minutes                        Total eve minutes             \
#                    mean        std amin   amax              mean        std
# Churn
# 0            175.175754  50.181655  0.0  315.6        199.043298  50.292175
# 1            206.914079  68.997792  0.0  350.8        212.410145  51.728910
#
#                    Total night minutes
#        amin   amax                mean        std  amin   amax
# Churn
# 0       0.0  361.8          200.133193  51.105032  23.2  395.0
# 1      70.9  363.7          205.231677  47.132825  47.4  354.9

# %%
pd.crosstab(df['Churn'], df['International plan'])
# Out:
# International plan  False  True
# Churn
# 0                    2664    186
# 1                     346    137

# %%
pd.crosstab(df['Churn'], df['Voice mail plan'], normalize=True)
# Out:
# Voice mail plan     False     True
# Churn
# 0                0.602460  0.252625
# 1                0.120912  0.024002

# %%
pd.crosstab(df['Churn'], df['Voice mail plan'], normalize=True).plot.bar(stacked=True)

# %%
df.pivot_table(['Total day calls', 'Total eve calls', 'Total night calls'], 
['Area code'], aggfunc='mean')
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190

# %%
total_calls = df['Total day calls'] + df['Total eve calls'] + \
                  df['Total night calls'] + df['Total intl calls']
df.insert(loc=len(df.columns), column='Total calls', value=total_calls) 
# loc - номер столбца, после которого нужно вставить данный Series
# мы указали len(df.columns), чтобы вставить его в самом конце
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
df['Total charge'] = df['Total day charge'] + df['Total eve charge'] + df['Total night charge'] + df['Total intl charge']

df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# ...

# %%
#df = df.drop(['Total charge', 'Total calls'], axis=1) 
df.head()
#df.drop([1, 2]).head() # а вот так можно удалить строчки
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# # Начало предварительного анализа

# %%
pd.crosstab(df['Churn'], df['International plan'], margins=True)
# Out:
# International plan  False  True   All
# Churn
# 0                    2664   186  2850
# 1                     346   137   483
# All                  3010   323  3333

# %%
df.pivot_table(['Total day calls', 'Total eve calls', 'Total night calls'], 
['Area code'])
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190

# %%
pd.crosstab(df['Churn'], df['International plan'], margins=True, margins_name= 'Total')
# Out:
# International plan  False  True  Total
# Churn
# 0                    2664   186   2850
# 1                     346   137    483
# Total                3010   323   3333
